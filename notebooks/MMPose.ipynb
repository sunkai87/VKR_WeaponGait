# %%
# !pip install openmim
# Out:
# ...
#      -------------------------------------- 52.7/52.7 kB 339.4 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.8/1.8 MB 679.7 kB/s eta 0:00:00
# ...
#      -------------------------------------- 311.5/311.5 kB 1.0 MB/s eta 0:00:00
# ...
#      ------------------------------------ 953.1/953.1 kB 973.0 kB/s eta 0:00:00
# ...
#      -------------------------------------- 62.8/62.8 kB 674.1 kB/s eta 0:00:00
# ...
#      ------------------------------------ 239.4/239.4 kB 861.5 kB/s eta 0:00:00
# ...
#      ------------------------------------ 259.5/259.5 kB 692.5 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 506.5/506.5 kB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 77.1/77.1 kB 613.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 65.5/65.5 kB 1.2 MB/s eta 0:00:00
# ...

# %%
# !mim install mmcv
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cpu/torch2.6.0/index.html
# ...
#      ------------------------------------ 479.1/479.1 kB 468.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ------------------------------------ 452.7/452.7 kB 644.1 kB/s eta 0:00:00
# ...
#   Created wheel for mmcv: filename=mmcv-2.2.0-cp39-cp39-win_amd64.whl size=1073026 sha256=7977acd760e8d5481f7675e9a4dc89bf1f6c795bb7e7f85e27259ed7ab76dc5d
#   Stored in directory: c:\users\vkash\appdata\local\pip\cache\wheels\d4\4b\87\51dd18771b527fb1559f11f7153a5f056d5d872135a7dcb5f5
# Successfully built mmcv
# ...
# C:\Users\vkash\anaconda3\lib\site-packages\torch\utils\_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
